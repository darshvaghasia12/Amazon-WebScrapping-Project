# %%
#import libraries
from bs4 import BeautifulSoup
import requests

import time
import datetime
import csv

import smtplib #Sends Emails to ourself

# %%
# Connect to the wwebsite

URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()


print(title)
print(price)
# Out:
#                     Funny Got Data MIS Data Systems Business Analyst T-Shirt
#
#
#
#
#
#                     $16.99
#
#
#
#
#
#
#                       $
#
#
#                       16
#
#                        .
#
#
#
#                       99

# %%
price = price.strip()[1:6]
title = title.strip()

print(title)
print(price)
# type(price)
# Out:
# Funny Got Data MIS Data Systems Business Analyst T-Shirt
# 16.99

# %%
import datetime
today = datetime.date.today()
print(today)
# Out:
# 2024-03-29

# %%
header = ['Title', 'Price', 'Date']
data = [title, price, today]


# with open('AmazonWebScrapperDataset.csv', 'w', newline='', encoding='UTF8') as f:
#   writer = csv.writer(f)
#   writer.writerow(header)
#   writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r'/content/AmazonWebScrapperDataset.csv')
df
# Out:
#                                                Title  Price        Date
# 0  Funny Got Data MIS Data Systems Business Analy...  16.99  2024-03-29

# %%
# Now we are appending data to the CSV

with open('AmazonWebScrapperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
  writer = csv.writer(f)
  writer.writerow(data)

# %%
def check_price():
  URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

  headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

  page = requests.get(URL, headers=headers)

  soup1 = BeautifulSoup(page.content, "html.parser")

  soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

  title = soup2.find(id='productTitle').get_text()

  price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()

  price = price.strip()[1:6]
  title = title.strip()
  import datetime
  today = datetime.date.today()

  import csv
  header = ['Title', 'Price', 'Date']
  data = [title, price, today]

  with open('AmazonWebScrapperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
      writer = csv.writer(f)
      writer.writerow(data)


  if(price < '18'):
    send_mail()

# %%
while(True):
  check_price()
  time.sleep(4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-22b5aa374b5a> in <cell line: 1>()
#       1 while(True):
#       2   check_price()
# ----> 3   time.sleep(4)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(r'/content/AmazonWebScrapperDataset.csv')
df
# Out:
#                                                Title  Price        Date
# 0  Funny Got Data MIS Data Systems Business Analy...  16.99  2024-03-29
# 1  Funny Got Data MIS Data Systems Business Analy...  16.99  2024-03-29
# 2  Funny Got Data MIS Data Systems Business Analy...  16.99  2024-03-29
# 3  Funny Got Data MIS Data Systems Business Analy...  16.99  2024-03-29
# 4  Funny Got Data MIS Data Systems Business Analy...  16.99  2024-03-29

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com')
    server.ehlo()
    # server.starttls()
    server.ehlo()
    server.login('darshvaghasia256@gmail.com','ygrr fpgx yruu yqib')

    subject = "The Shirt you want is below $14! Now is your chance to buy!"
    body = "Darsh, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"

    msg = f"Subject: {subject}\n\n{body}"
    # msg = subject + body
    server.sendmail('darshvaghasia256@gmail.com','darshvaghasia256@gmail.com',msg)
